# %% [markdown]
# ### MBTA API Discovery
#
# The MBTA API is well documented at https://api-v3.mbta.com/docs/swagger/index.html#/Stop/ApiWeb_StopController_index. With this documentation, a few things were made apparent.
#
# 1. An API key isn't needed to use the MBTA API, but you'll encounter throttling more quickly if you don't have one.
# 2. API Keys are free if you sign up at https://api-v3.mbta.com/portal.

# %%
import requests
import json

# %%
# TODO Add api-key consumption through os library
session = requests.Session()
session.headers = {
    'x-api-key': '87be91c1ed1a41eeae2b10f96153769d',
    'User-Agent': 'Charlie Tracker',
}
session.params = {
    'page[limit]': 50,
}
mbta_url = 'https://api-v3.mbta.com'
response = session.get(f'{mbta_url}/routes',)
# TODO Throw exceptions for non 200 status codes.

# %%
response_data = response.json()

# %%
response_data['data']
# Out:
# [{'attributes': {'color': 'DA291C',
#    'description': 'Rapid Transit',
#    'direction_destinations': ['Ashmont/Braintree', 'Alewife'],
#    'direction_names': ['South', 'North'],
#    'fare_class': 'Rapid Transit',
#    'long_name': 'Red Line',
#    'short_name': '',
#    'sort_order': 10010,
#    'text_color': 'FFFFFF',
#    'type': 1},
#   'id': 'Red',
#   'links': {'self': '/routes/Red'},
#   'relationships': {'line': {'data': {'id': 'line-Red', 'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'},
#  {'attributes': {'color': 'DA291C',
#    'description': 'Rapid Transit',
#    'direction_destinations': ['Mattapan', 'Ashmont'],
#    'direction_names': ['Outbound', 'Inbound'],
#    'fare_class': 'Rapid Transit',
#    'long_name': 'Mattapan Trolley',
#    'short_name': '',
#    'sort_order': 10011,
#    'text_color': 'FFFFFF',
#    'type': 0},
#   'id': 'Mattapan',
#   'links': {'self': '/routes/Mattapan'},
#   'relationships': {'line': {'data': {'id': 'line-Mattapan', 'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'},
#  {'attributes': {'color': 'ED8B00',
#    'description': 'Rapid Transit',
#    'direction_destinations': ['Forest Hills', 'Oak Grove'],
#    'direction_names': ['South', 'North'],
#    'fare_class': 'Rapid Transit',
#    'long_name': 'Orange Line',
#    'short_name': '',
#    'sort_order': 10020,
#    'text_color': 'FFFFFF',
#    'type': 1},
#   'id': 'Orange',
#   'links': {'self': '/routes/Orange'},
#   'relationships': {'line': {'data': {'id': 'line-Orange', 'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'},
#  {'attributes': {'color': '00843D',
#    'description': 'Rapid Transit',
#    'direction_destinations': ['Boston College', 'Park Street'],
#    'direction_names': ['West', 'East'],
#    'fare_class': 'Rapid Transit',
#    'long_name': 'Green Line B',
#    'short_name': 'B',
#    'sort_order': 10032,
#    'text_color': 'FFFFFF',
#    'type': 0},
#   'id': 'Green-B',
#   'links': {'self': '/routes/Green-B'},
#   'relationships': {'line': {'data': {'id': 'line-Green', 'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'},
#  {'attributes': {'color': '00843D',
#    'description': 'Rapid Transit',
#    'direction_destinations': ['Cleveland Circle', 'North Station'],
#    'direction_names': ['West', 'East'],
#    'fare_class': 'Rapid Transit',
#    'long_name': 'Green Line C',
#    'short_name': 'C',
#    'sort_order': 10033,
#    'text_color': 'FFFFFF',
#    'type': 0},
#   'id': 'Green-C',
#   'links': {'self': '/routes/Green-C'},
#   'relationships': {'line': {'data': {'id': 'line-Green', 'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'},
#  {'attributes': {'color': '00843D',
#    'description': 'Rapid Transit',
#    'direction_destinations': ['Riverside', 'Government Center'],
#    'direction_names': ['West', 'East'],
#    'fare_class': 'Rapid Transit',
#    'long_name': 'Green Line D',
#    'short_name': 'D',
#    'sort_order': 10034,
#    'text_color': 'FFFFFF',
#    'type': 0},
#   'id': 'Green-D',
#   'links': {'self': '/routes/Green-D'},
#   'relationships': {'line': {'data': {'id': 'line-Green', 'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'},
#  {'attributes': {'color': '00843D',
#    'description': 'Rapid Transit',
#    'direction_destinations': ['Heath Street', 'North Station'],
#    'direction_names': ['West', 'East'],
#    'fare_class': 'Rapid Transit',
#    'long_name': 'Green Line E',
#    'short_name': 'E',
#    'sort_order': 10035,
#    'text_color': 'FFFFFF',
#    'type': 0},
#   'id': 'Green-E',
#   'links': {'self': '/routes/Green-E'},
#   'relationships': {'line': {'data': {'id': 'line-Green', 'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'},
#  {'attributes': {'color': '003DA5',
#    'description': 'Rapid Transit',
#    'direction_destinations': ['Bowdoin', 'Wonderland'],
#    'direction_names': ['West', 'East'],
#    'fare_class': 'Rapid Transit',
#    'long_name': 'Blue Line',
#    'short_name': '',
#    'sort_order': 10040,
#    'text_color': 'FFFFFF',
#    'type': 1},
#   'id': 'Blue',
#   'links': {'self': '/routes/Blue'},
#   'relationships': {'line': {'data': {'id': 'line-Blue', 'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'},
#  {'attributes': {'color': '7C878E',
#    'description': 'Key Bus',
#    'direction_destinations': ['Logan Airport Terminals', 'South Station'],
#    'direction_names': ['Outbound', 'Inbound'],
#    'fare_class': 'Rapid Transit',
#    'long_name': 'Logan Airport Terminals - South Station',
#    'short_name': 'SL1',
#    'sort_order': 10051,
#    'text_color': 'FFFFFF',
#    'type': 3},
#   'id': '741',
#   'links': {'self': '/routes/741'},
#   'relationships': {'line': {'data': {'id': 'line-SLWaterfront',
#      'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'},
#  {'attributes': {'color': '7C878E',
#    'description': 'Key Bus',
#    'direction_destinations': ['Drydock Avenue', 'South Station'],
#    'direction_names': ['Outbound', 'Inbound'],
#    'fare_class': 'Rapid Transit',
#    'long_name': 'Drydock Avenue - South Station',
#    'short_name': 'SL2',
#    'sort_order': 10052,
#    'text_color': 'FFFFFF',
#    'type': 3},
#   'id': '742',
#   'links': {'self': '/routes/742'},
#   'relationships': {'line': {'data': {'id': 'line-SLWaterfront',
#      'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'},
#  {'attributes': {'color': '7C878E',
#    'description': 'Key Bus',
#    'direction_destinations': ['Chelsea Station', 'South Station'],
#    'direction_names': ['Outbound', 'Inbound'],
#    'fare_class': 'Rapid Transit',
#    'long_name': 'Chelsea Station - South Station',
#    'short_name': 'SL3',
#    'sort_order': 10053,
#    'text_color': 'FFFFFF',
#    'type': 3},
#   'id': '743',
#   'links': {'self': '/routes/743'},
#   'relationships': {'line': {'data': {'id': 'line-SLWaterfront',
#      'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'},
#  {'attributes': {'color': '7C878E',
#    'description': 'Key Bus',
#    'direction_destinations': ['Nubian Station', 'South Station'],
#    'direction_names': ['Outbound', 'Inbound'],
#    'fare_class': 'Local Bus',
#    'long_name': 'Nubian Station - South Station',
#    'short_name': 'SL4',
#    'sort_order': 10055,
#    'text_color': 'FFFFFF',
#    'type': 3},
#   'id': '751',
#   'links': {'self': '/routes/751'},
#   'relationships': {'line': {'data': {'id': 'line-SLWashington',
#      'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'},
#  {'attributes': {'color': '7C878E',
#    'description': 'Key Bus',
#    'direction_destinations': ['Nubian Station', 'Temple Place'],
#    'direction_names': ['Outbound', 'Inbound'],
#    'fare_class': 'Local Bus',
#    'long_name': 'Nubian Station - Temple Place',
#    'short_name': 'SL5',
#    'sort_order': 10056,
#    'text_color': 'FFFFFF',
#    'type': 3},
#   'id': '749',
#   'links': {'self': '/routes/749'},
#   'relationships': {'line': {'data': {'id': 'line-SLWashington',
#      'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'},
#  {'attributes': {'color': '80276C',
#    'description': 'Commuter Rail',
#    'direction_destinations': ['Fairmount', 'South Station'],
#    'direction_names': ['Outbound', 'Inbound'],
#    'fare_class': 'Commuter Rail',
#    'long_name': 'Fairmount Line',
#    'short_name': '',
#    'sort_order': 20001,
#    'text_color': 'FFFFFF',
#    'type': 2},
#   'id': 'CR-Fairmount',
#   'links': {'self': '/routes/CR-Fairmount'},
#   'relationships': {'line': {'data': {'id': 'line-Fairmount', 'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'},
#  {'attributes': {'color': '80276C',
#    'description': 'Commuter Rail',
#    'direction_destinations': ['Wachusett', 'North Station'],
#    'direction_names': ['Outbound', 'Inbound'],
#    'fare_class': 'Commuter Rail',
#    'long_name': 'Fitchburg Line',
#    'short_name': '',
#    'sort_order': 20002,
#    'text_color': 'FFFFFF',
#    'type': 2},
#   'id': 'CR-Fitchburg',
#   'links': {'self': '/routes/CR-Fitchburg'},
#   'relationships': {'line': {'data': {'id': 'line-Fitchburg', 'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'},
#  {'attributes': {'color': '80276C',
#    'description': 'Commuter Rail',
#    'direction_destinations': ['Worcester', 'South Station'],
#    'direction_names': ['Outbound', 'Inbound'],
#    'fare_class': 'Commuter Rail',
#    'long_name': 'Framingham/Worcester Line',
#    'short_name': '',
#    'sort_order': 20003,
#    'text_color': 'FFFFFF',
#    'type': 2},
#   'id': 'CR-Worcester',
#   'links': {'self': '/routes/CR-Worcester'},
#   'relationships': {'line': {'data': {'id': 'line-Worcester', 'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'},
#  {'attributes': {'color': '80276C',
#    'description': 'Commuter Rail',
#    'direction_destinations': ['Forge Park/495', 'South Station'],
#    'direction_names': ['Outbound', 'Inbound'],
#    'fare_class': 'Commuter Rail',
#    'long_name': 'Franklin Line',
#    'short_name': '',
#    'sort_order': 20004,
#    'text_color': 'FFFFFF',
#    'type': 2},
#   'id': 'CR-Franklin',
#   'links': {'self': '/routes/CR-Franklin'},
#   'relationships': {'line': {'data': {'id': 'line-Franklin', 'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'},
#  {'attributes': {'color': '80276C',
#    'description': 'Commuter Rail',
#    'direction_destinations': ['Greenbush', 'South Station'],
#    'direction_names': ['Outbound', 'Inbound'],
#    'fare_class': 'Commuter Rail',
#    'long_name': 'Greenbush Line',
#    'short_name': '',
#    'sort_order': 20005,
#    'text_color': 'FFFFFF',
#    'type': 2},
#   'id': 'CR-Greenbush',
#   'links': {'self': '/routes/CR-Greenbush'},
#   'relationships': {'line': {'data': {'id': 'line-Greenbush', 'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'},
#  {'attributes': {'color': '80276C',
#    'description': 'Commuter Rail',
#    'direction_destinations': ['Haverhill', 'North Station'],
#    'direction_names': ['Outbound', 'Inbound'],
#    'fare_class': 'Commuter Rail',
#    'long_name': 'Haverhill Line',
#    'short_name': '',
#    'sort_order': 20006,
#    'text_color': 'FFFFFF',
#    'type': 2},
#   'id': 'CR-Haverhill',
#   'links': {'self': '/routes/CR-Haverhill'},
#   'relationships': {'line': {'data': {'id': 'line-Haverhill', 'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'},
#  {'attributes': {'color': '80276C',
#    'description': 'Commuter Rail',
#    'direction_destinations': ['Kingston or Plymouth', 'South Station'],
#    'direction_names': ['Outbound', 'Inbound'],
#    'fare_class': 'Commuter Rail',
#    'long_name': 'Kingston/Plymouth Line',
#    'short_name': '',
#    'sort_order': 20007,
#    'text_color': 'FFFFFF',
#    'type': 2},
#   'id': 'CR-Kingston',
#   'links': {'self': '/routes/CR-Kingston'},
#   'relationships': {'line': {'data': {'id': 'line-Kingston', 'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'},
#  {'attributes': {'color': '80276C',
#    'description': 'Commuter Rail',
#    'direction_destinations': ['Lowell', 'North Station'],
#    'direction_names': ['Outbound', 'Inbound'],
#    'fare_class': 'Commuter Rail',
#    'long_name': 'Lowell Line',
#    'short_name': '',
#    'sort_order': 20008,
#    'text_color': 'FFFFFF',
#    'type': 2},
#   'id': 'CR-Lowell',
#   'links': {'self': '/routes/CR-Lowell'},
#   'relationships': {'line': {'data': {'id': 'line-Lowell', 'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'},
#  {'attributes': {'color': '80276C',
#    'description': 'Commuter Rail',
#    'direction_destinations': ['Middleborough/Lakeville', 'South Station'],
#    'direction_names': ['Outbound', 'Inbound'],
#    'fare_class': 'Commuter Rail',
#    'long_name': 'Middleborough/Lakeville Line',
#    'short_name': '',
#    'sort_order': 20009,
#    'text_color': 'FFFFFF',
#    'type': 2},
#   'id': 'CR-Middleborough',
#   'links': {'self': '/routes/CR-Middleborough'},
#   'relationships': {'line': {'data': {'id': 'line-Middleborough',
#      'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'},
#  {'attributes': {'color': '80276C',
#    'description': 'Commuter Rail',
#    'direction_destinations': ['Needham Heights', 'South Station'],
#    'direction_names': ['Outbound', 'Inbound'],
#    'fare_class': 'Commuter Rail',
#    'long_name': 'Needham Line',
#    'short_name': '',
#    'sort_order': 20010,
#    'text_color': 'FFFFFF',
#    'type': 2},
#   'id': 'CR-Needham',
#   'links': {'self': '/routes/CR-Needham'},
#   'relationships': {'line': {'data': {'id': 'line-Needham', 'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'},
#  {'attributes': {'color': '80276C',
#    'description': 'Commuter Rail',
#    'direction_destinations': ['Newburyport or Rockport', 'North Station'],
#    'direction_names': ['Outbound', 'Inbound'],
#    'fare_class': 'Commuter Rail',
#    'long_name': 'Newburyport/Rockport Line',
#    'short_name': '',
#    'sort_order': 20011,
#    'text_color': 'FFFFFF',
#    'type': 2},
#   'id': 'CR-Newburyport',
#   'links': {'self': '/routes/CR-Newburyport'},
#   'relationships': {'line': {'data': {'id': 'line-Newburyport',
#      'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'},
#  {'attributes': {'color': '80276C',
#    'description': 'Commuter Rail',
#    'direction_destinations': ['Stoughton or Wickford Junction',
#     'South Station'],
#    'direction_names': ['Outbound', 'Inbound'],
#    'fare_class': 'Commuter Rail',
#    'long_name': 'Providence/Stoughton Line',
#    'short_name': '',
#    'sort_order': 20012,
#    'text_color': 'FFFFFF',
#    'type': 2},
#   'id': 'CR-Providence',
#   'links': {'self': '/routes/CR-Providence'},
#   'relationships': {'line': {'data': {'id': 'line-Providence',
#      'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'},
#  {'attributes': {'color': '80276C',
#    'description': 'Commuter Rail',
#    'direction_destinations': ['Foxboro or Providence',
#     'South Station or Foxboro'],
#    'direction_names': ['Outbound', 'Inbound'],
#    'fare_class': 'Commuter Rail',
#    'long_name': 'Foxboro Event Service',
#    'short_name': '',
#    'sort_order': 20013,
#    'text_color': 'FFFFFF',
#    'type': 2},
#   'id': 'CR-Foxboro',
#   'links': {'self': '/routes/CR-Foxboro'},
#   'relationships': {'line': {'data': {'id': 'line-Foxboro', 'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'},
#  {'attributes': {'color': '008EAA',
#    'description': 'Ferry',
#    'direction_destinations': ['Charlestown', 'Long Wharf'],
#    'direction_names': ['Outbound', 'Inbound'],
#    'fare_class': 'Ferry',
#    'long_name': 'Charlestown Ferry',
#    'short_name': '',
#    'sort_order': 30001,
#    'text_color': 'FFFFFF',
#    'type': 4},
#   'id': 'Boat-F4',
#   'links': {'self': '/routes/Boat-F4'},
#   'relationships': {'line': {'data': {'id': 'line-Boat-F4', 'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'},
#  {'attributes': {'color': '008EAA',
#    'description': 'Ferry',
#    'direction_destinations': ['Hingham or Hull', 'Long Wharf or Rowes Wharf'],
#    'direction_names': ['Outbound', 'Inbound'],
#    'fare_class': 'Ferry',
#    'long_name': 'Hingham/Hull Ferry',
#    'short_name': '',
#    'sort_order': 30002,
#    'text_color': 'FFFFFF',
#    'type': 4},
#   'id': 'Boat-F1',
#   'links': {'self': '/routes/Boat-F1'},
#   'relationships': {'line': {'data': {'id': 'line-Boat-F1', 'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'},
#  {'attributes': {'color': 'FFC72C',
#    'description': 'Local Bus',
#    'direction_destinations': ['Sullivan Square Station', 'Ruggles Station'],
#    'direction_names': ['Outbound', 'Inbound'],
#    'fare_class': 'Local Bus',
#    'long_name': 'Sullivan Square Station - Ruggles Station',
#    'short_name': 'CT2',
#    'sort_order': 40020,
#    'text_color': '000000',
#    'type': 3},
#   'id': '747',
#   'links': {'self': '/routes/747'},
#   'relationships': {'line': {'data': {'id': 'line-747', 'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'},
#  {'attributes': {'color': 'FFC72C',
#    'description': 'Local Bus',
#    'direction_destinations': ['Beth Israel Deaconess Hospital',
#     'Andrew Station'],
#    'direction_names': ['Outbound', 'Inbound'],
#    'fare_class': 'Local Bus',
#    'long_name': 'Beth Israel Deaconess Hospital - Andrew Station',
#    'short_name': 'CT3',
#    'sort_order': 40030,
#    'text_color': '000000',
#    'type': 3},
#   'id': '708',
#   'links': {'self': '/routes/708'},
#   'relationships': {'line': {'data': {'id': 'line-171708', 'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'},
#  {'attributes': {'color': 'FFC72C',
#    'description': 'Key Bus',
#    'direction_destinations': ['Harvard Square', 'Nubian Station'],
#    'direction_names': ['Outbound', 'Inbound'],
#    'fare_class': 'Local Bus',
#    'long_name': 'Harvard Square - Nubian Station',
#    'short_name': '1',
#    'sort_order': 50010,
#    'text_color': '000000',
#    'type': 3},
#   'id': '1',
#   'links': {'self': '/routes/1'},
#   'relationships': {'line': {'data': {'id': 'line-1', 'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'},
#  {'attributes': {'color': 'FFC72C',
#    'description': 'Commuter Bus',
#    'direction_destinations': ['North Station', 'Tide Street'],
#    'direction_names': ['Outbound', 'Inbound'],
#    'fare_class': 'Local Bus',
#    'long_name': 'North Station - Tide Street',
#    'short_name': '4',
#    'sort_order': 50040,
#    'text_color': '000000',
#    'type': 3},
#   'id': '4',
#   'links': {'self': '/routes/4'},
#   'relationships': {'line': {'data': {'id': 'line-4', 'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'},
#  {'attributes': {'color': 'FFC72C',
#    'description': 'Local Bus',
#    'direction_destinations': ['City Point', 'Otis Street & Summer Street'],
#    'direction_names': ['Outbound', 'Inbound'],
#    'fare_class': 'Local Bus',
#    'long_name': 'City Point - Otis Street & Summer Street',
#    'short_name': '7',
#    'sort_order': 50070,
#    'text_color': '000000',
#    'type': 3},
#   'id': '7',
#   'links': {'self': '/routes/7'},
#   'relationships': {'line': {'data': {'id': 'line-7', 'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'},
#  {'attributes': {'color': 'FFC72C',
#    'description': 'Local Bus',
#    'direction_destinations': ['Harbor Point', 'Kenmore Station'],
#    'direction_names': ['Outbound', 'Inbound'],
#    'fare_class': 'Local Bus',
#    'long_name': 'Harbor Point - Kenmore Station',
#    'short_name': '8',
#    'sort_order': 50080,
#    'text_color': '000000',
#    'type': 3},
#   'id': '8',
#   'links': {'self': '/routes/8'},
#   'relationships': {'line': {'data': {'id': 'line-8', 'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'},
#  {'attributes': {'color': 'FFC72C',
#    'description': 'Local Bus',
#    'direction_destinations': ['City Point', 'Copley Station'],
#    'direction_names': ['Outbound', 'Inbound'],
#    'fare_class': 'Local Bus',
#    'long_name': 'City Point - Copley Station',
#    'short_name': '9',
#    'sort_order': 50090,
#    'text_color': '000000',
#    'type': 3},
#   'id': '9',
#   'links': {'self': '/routes/9'},
#   'relationships': {'line': {'data': {'id': 'line-9', 'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'},
#  {'attributes': {'color': 'FFC72C',
#    'description': 'Local Bus',
#    'direction_destinations': ['City Point', 'Copley Square'],
#    'direction_names': ['Outbound', 'Inbound'],
#    'fare_class': 'Local Bus',
#    'long_name': 'City Point - Copley Square',
#    'short_name': '10',
#    'sort_order': 50100,
#    'text_color': '000000',
#    'type': 3},
#   'id': '10',
#   'links': {'self': '/routes/10'},
#   'relationships': {'line': {'data': {'id': 'line-10', 'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'},
#  {'attributes': {'color': 'FFC72C',
#    'description': 'Local Bus',
#    'direction_destinations': ['City Point', 'Chauncy Street & Summer Street'],
#    'direction_names': ['Outbound', 'Inbound'],
#    'fare_class': 'Local Bus',
#    'long_name': 'City Point - Chauncy Street & Summer Street',
#    'short_name': '11',
#    'sort_order': 50110,
#    'text_color': '000000',
#    'type': 3},
#   'id': '11',
#   'links': {'self': '/routes/11'},
#   'relationships': {'line': {'data': {'id': 'line-11', 'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'},
#  {'attributes': {'color': 'FFC72C',
#    'description': 'Local Bus',
#    'direction_destinations': ['Roslindale Square', 'Heath Street'],
#    'direction_names': ['Outbound', 'Inbound'],
#    'fare_class': 'Local Bus',
#    'long_name': 'Roslindale Square - Heath Street',
#    'short_name': '14',
#    'sort_order': 50140,
#    'text_color': '000000',
#    'type': 3},
#   'id': '14',
#   'links': {'self': '/routes/14'},
#   'relationships': {'line': {'data': {'id': 'line-14', 'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'},
#  {'attributes': {'color': 'FFC72C',
#    'description': 'Key Bus',
#    'direction_destinations': ['Fields Corner Station or Kane Square',
#     'Ruggles Station'],
#    'direction_names': ['Outbound', 'Inbound'],
#    'fare_class': 'Local Bus',
#    'long_name': 'Fields Corner Station or Kane Square - Ruggles Station',
#    'short_name': '15',
#    'sort_order': 50150,
#    'text_color': '000000',
#    'type': 3},
#   'id': '15',
#   'links': {'self': '/routes/15'},
#   'relationships': {'line': {'data': {'id': 'line-15', 'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'},
#  {'attributes': {'color': 'FFC72C',
#    'description': 'Local Bus',
#    'direction_destinations': ['Forest Hills Station',
#     'Andrew Station or Harbor Point'],
#    'direction_names': ['Outbound', 'Inbound'],
#    'fare_class': 'Local Bus',
#    'long_name': 'Forest Hills Station - Andrew Station or Harbor Point',
#    'short_name': '16',
#    'sort_order': 50160,
#    'text_color': '000000',
#    'type': 3},
#   'id': '16',
#   'links': {'self': '/routes/16'},
#   'relationships': {'line': {'data': {'id': 'line-16', 'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'},
#  {'attributes': {'color': 'FFC72C',
#    'description': 'Local Bus',
#    'direction_destinations': ['Fields Corner Station', 'Andrew Station'],
#    'direction_names': ['Outbound', 'Inbound'],
#    'fare_class': 'Local Bus',
#    'long_name': 'Fields Corner Station - Andrew Station',
#    'short_name': '17',
#    'sort_order': 50170,
#    'text_color': '000000',
#    'type': 3},
#   'id': '17',
#   'links': {'self': '/routes/17'},
#   'relationships': {'line': {'data': {'id': 'line-1719', 'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'},
#  {'attributes': {'color': 'FFC72C',
#    'description': 'Local Bus',
#    'direction_destinations': ['Ashmont Station', 'Andrew Station'],
#    'direction_names': ['Outbound', 'Inbound'],
#    'fare_class': 'Local Bus',
#    'long_name': 'Ashmont Station - Andrew Station',
#    'short_name': '18',
#    'sort_order': 50180,
#    'text_color': '000000',
#    'type': 3},
#   'id': '18',
#   'links': {'self': '/routes/18'},
#   'relationships': {'line': {'data': {'id': 'line-18', 'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'},
#  {'attributes': {'color': 'FFC72C',
#    'description': 'Local Bus',
#    'direction_destinations': ['Fields Corner Station',
#     'Kenmore or Ruggles Station'],
#    'direction_names': ['Outbound', 'Inbound'],
#    'fare_class': 'Local Bus',
#    'long_name': 'Fields Corner Station - Kenmore or Ruggles Station',
#    'short_name': '19',
#    'sort_order': 50190,
#    'text_color': '000000',
#    'type': 3},
#   'id': '19',
#   'links': {'self': '/routes/19'},
#   'relationships': {'line': {'data': {'id': 'line-1719', 'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'},
#  {'attributes': {'color': 'FFC72C',
#    'description': 'Local Bus',
#    'direction_destinations': ['Ashmont Station', 'Forest Hills Station'],
#    'direction_names': ['Outbound', 'Inbound'],
#    'fare_class': 'Local Bus',
#    'long_name': 'Ashmont Station - Forest Hills Station',
#    'short_name': '21',
#    'sort_order': 50210,
#    'text_color': '000000',
#    'type': 3},
#   'id': '21',
#   'links': {'self': '/routes/21'},
#   'relationships': {'line': {'data': {'id': 'line-21', 'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'},
#  {'attributes': {'color': 'FFC72C',
#    'description': 'Key Bus',
#    'direction_destinations': ['Ashmont Station', 'Ruggles Station'],
#    'direction_names': ['Outbound', 'Inbound'],
#    'fare_class': 'Local Bus',
#    'long_name': 'Ashmont Station - Ruggles Station via Talbot Ave',
#    'short_name': '22',
#    'sort_order': 50220,
#    'text_color': '000000',
#    'type': 3},
#   'id': '22',
#   'links': {'self': '/routes/22'},
#   'relationships': {'line': {'data': {'id': 'line-22', 'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'},
#  {'attributes': {'color': 'FFC72C',
#    'description': 'Key Bus',
#    'direction_destinations': ['Ashmont Station', 'Ruggles Station'],
#    'direction_names': ['Outbound', 'Inbound'],
#    'fare_class': 'Local Bus',
#    'long_name': 'Ashmont Station - Ruggles Station via Washington Street',
#    'short_name': '23',
#    'sort_order': 50230,
#    'text_color': '000000',
#    'type': 3},
#   'id': '23',
#   'links': {'self': '/routes/23'},
#   'relationships': {'line': {'data': {'id': 'line-23', 'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'},
#  {'attributes': {'color': 'FFC72C',
#    'description': 'Local Bus',
#    'direction_destinations': ['Wakefield Avenue & Truman Parkway',
#     'Mattapan Station'],
#    'direction_names': ['Outbound', 'Inbound'],
#    'fare_class': 'Local Bus',
#    'long_name': 'Wakefield Avenue & Truman Parkway - Mattapan Station',
#    'short_name': '24',
#    'sort_order': 50240,
#    'text_color': '000000',
#    'type': 3},
#   'id': '24',
#   'links': {'self': '/routes/24'},
#   'relationships': {'line': {'data': {'id': 'line-242733', 'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'},
#  {'attributes': {'color': 'FFC72C',
#    'description': 'Local Bus',
#    'direction_destinations': ['Ashmont Station', 'Norfolk Street Loop'],
#    'direction_names': ['Outbound', 'Inbound'],
#    'fare_class': 'Local Bus',
#    'long_name': 'Ashmont Station - Norfolk Street Loop',
#    'short_name': '26',
#    'sort_order': 50260,
#    'text_color': '000000',
#    'type': 3},
#   'id': '26',
#   'links': {'self': '/routes/26'},
#   'relationships': {'line': {'data': {'id': 'line-26', 'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'},
#  {'attributes': {'color': 'FFC72C',
#    'description': 'Local Bus',
#    'direction_destinations': ['Mattapan Station', 'Ashmont Station'],
#    'direction_names': ['Outbound', 'Inbound'],
#    'fare_class': 'Local Bus',
#    'long_name': 'Mattapan Station - Ashmont Station',
#    'short_name': '27',
#    'sort_order': 50270,
#    'text_color': '000000',
#    'type': 3},
#   'id': '27',
#   'links': {'self': '/routes/27'},
#   'relationships': {'line': {'data': {'id': 'line-242733', 'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'},
#  {'attributes': {'color': 'FFC72C',
#    'description': 'Key Bus',
#    'direction_destinations': ['Mattapan Station', 'Ruggles Station'],
#    'direction_names': ['Outbound', 'Inbound'],
#    'fare_class': 'Local Bus',
#    'long_name': 'Mattapan Station - Ruggles Station',
#    'short_name': '28',
#    'sort_order': 50280,
#    'text_color': '000000',
#    'type': 3},
#   'id': '28',
#   'links': {'self': '/routes/28'},
#   'relationships': {'line': {'data': {'id': 'line-28', 'type': 'line'}},
#    'route_patterns': {}},
#   'type': 'route'}]

# %%
for route in response_data['data']:
    print(f"ID: {route['id']+',':<17} NAME: {route['attributes']['long_name']}")
# Out:
# ID: Red,              NAME: Red Line
# ID: Mattapan,         NAME: Mattapan Trolley
# ID: Orange,           NAME: Orange Line
# ID: Green-B,          NAME: Green Line B
# ID: Green-C,          NAME: Green Line C
# ID: Green-D,          NAME: Green Line D
# ID: Green-E,          NAME: Green Line E
# ID: Blue,             NAME: Blue Line
# ID: 741,              NAME: Logan Airport Terminals - South Station
# ID: 742,              NAME: Drydock Avenue - South Station
# ID: 743,              NAME: Chelsea Station - South Station
# ID: 751,              NAME: Nubian Station - South Station
# ID: 749,              NAME: Nubian Station - Temple Place
# ID: CR-Fairmount,     NAME: Fairmount Line
# ID: CR-Fitchburg,     NAME: Fitchburg Line
# ID: CR-Worcester,     NAME: Framingham/Worcester Line
# ID: CR-Franklin,      NAME: Franklin Line
# ID: CR-Greenbush,     NAME: Greenbush Line
# ID: CR-Haverhill,     NAME: Haverhill Line
# ID: CR-Kingston,      NAME: Kingston/Plymouth Line
# ID: CR-Lowell,        NAME: Lowell Line
# ID: CR-Middleborough, NAME: Middleborough/Lakeville Line
# ID: CR-Needham,       NAME: Needham Line
# ID: CR-Newburyport,   NAME: Newburyport/Rockport Line
# ID: CR-Providence,    NAME: Providence/Stoughton Line
# ID: CR-Foxboro,       NAME: Foxboro Event Service
# ID: Boat-F4,          NAME: Charlestown Ferry
# ID: Boat-F1,          NAME: Hingham/Hull Ferry
# ID: 747,              NAME: Sullivan Square Station - Ruggles Station
# ID: 708,              NAME: Beth Israel Deaconess Hospital - Andrew Station
# ID: 1,                NAME: Harvard Square - Nubian Station
# ID: 4,                NAME: North Station - Tide Street
# ID: 7,                NAME: City Point - Otis Street & Summer Street
# ID: 8,                NAME: Harbor Point - Kenmore Station
# ID: 9,                NAME: City Point - Copley Station
# ID: 10,               NAME: City Point - Copley Square
# ID: 11,               NAME: City Point - Chauncy Street & Summer Street
# ID: 14,               NAME: Roslindale Square - Heath Street
# ID: 15,               NAME: Fields Corner Station or Kane Square - Ruggles Station
# ID: 16,               NAME: Forest Hills Station - Andrew Station or Harbor Point
# ID: 17,               NAME: Fields Corner Station - Andrew Station
# ID: 18,               NAME: Ashmont Station - Andrew Station
# ID: 19,               NAME: Fields Corner Station - Kenmore or Ruggles Station
# ID: 21,               NAME: Ashmont Station - Forest Hills Station
# ID: 22,               NAME: Ashmont Station - Ruggles Station via Talbot Ave
# ID: 23,               NAME: Ashmont Station - Ruggles Station via Washington Street
# ID: 24,               NAME: Wakefield Avenue & Truman Parkway - Mattapan Station
# ID: 26,               NAME: Ashmont Station - Norfolk Street Loop
# ID: 27,               NAME: Mattapan Station - Ashmont Station
# ID: 28,               NAME: Mattapan Station - Ruggles Station

# %%
response_data['links'].get('next', False)
# Out:
# 'https://api-v3.mbta.com/routes?page[limit]=50&page[offset]=50'

# %%
response_data['links']
# Out:
# {'first': 'https://api-v3.mbta.com/routes?page[limit]=50&page[offset]=0',
#  'last': 'https://api-v3.mbta.com/routes?page[limit]=50&page[offset]=150',
#  'next': 'https://api-v3.mbta.com/routes?page[limit]=50&page[offset]=50'}

# %%
route_id = 'Red'
response2 = session.get(f"{mbta_url}/stops", params = {'filter[route]': route_id})

# %%
response2_data = response2.json()

# %%
for stop in response2_data['data']:
    print(f"ID: {stop['id']+',':<15} NAME: {stop['attributes']['name']}")
# Out:
# ID: place-alfcl,    NAME: Alewife
# ID: place-davis,    NAME: Davis
# ID: place-portr,    NAME: Porter
# ID: place-harsq,    NAME: Harvard
# ID: place-cntsq,    NAME: Central
# ID: place-knncl,    NAME: Kendall/MIT
# ID: place-chmnl,    NAME: Charles/MGH
# ID: place-pktrm,    NAME: Park Street
# ID: place-dwnxg,    NAME: Downtown Crossing
# ID: place-sstat,    NAME: South Station
# ID: place-brdwy,    NAME: Broadway
# ID: place-andrw,    NAME: Andrew
# ID: place-jfk,      NAME: JFK/UMass
# ID: place-shmnl,    NAME: Savin Hill
# ID: place-fldcr,    NAME: Fields Corner
# ID: place-smmnl,    NAME: Shawmut
# ID: place-asmnl,    NAME: Ashmont
# ID: place-nqncy,    NAME: North Quincy
# ID: place-wlsta,    NAME: Wollaston
# ID: place-qnctr,    NAME: Quincy Center
# ID: place-qamnl,    NAME: Quincy Adams
# ID: place-brntn,    NAME: Braintree

# %%
print(response2_data['links'].get('next', False))
# Out:
# False

# %%
route_id = 'Red'
response3 = session.get(f"{mbta_url}/stops", params = None)

# %%
response3_data = response3.json()['data']

# %%
response3_data
# Out:
# [{'attributes': {'address': None,
#    'at_street': None,
#    'description': None,
#    'latitude': 42.489729,
#    'location_type': 0,
#    'longitude': -70.968996,
#    'municipality': 'Lynn',
#    'name': 'Lynnfield St @ St Mary Cemetery',
#    'on_street': 'Lynnfield Street',
#    'platform_code': None,
#    'platform_name': None,
#    'vehicle_type': 3,
#    'wheelchair_boarding': 0},
#   'id': '17354',
#   'links': {'self': '/stops/17354'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=17354'}},
#    'parent_station': {'data': None},
#    'recommended_transfers': {},
#    'zone': {'data': {'id': 'LocalBus', 'type': 'zone'}}},
#   'type': 'stop'},
#  {'attributes': {'address': None,
#    'at_street': 'Saint Richard Street',
#    'description': None,
#    'latitude': 42.323534,
#    'location_type': 0,
#    'longitude': -71.084009,
#    'municipality': 'Boston',
#    'name': 'Walnut Ave @ St Richard St',
#    'on_street': 'Walnut Avenue',
#    'platform_code': None,
#    'platform_name': None,
#    'vehicle_type': 3,
#    'wheelchair_boarding': 0},
#   'id': '1339',
#   'links': {'self': '/stops/1339'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=1339'}},
#    'parent_station': {'data': None},
#    'recommended_transfers': {},
#    'zone': {'data': {'id': 'LocalBus', 'type': 'zone'}}},
#   'type': 'stop'},
#  {'attributes': {'address': None,
#    'at_street': 'Page Road',
#    'description': None,
#    'latitude': 42.353395,
#    'location_type': 0,
#    'longitude': -71.208103,
#    'municipality': 'Newton',
#    'name': 'Walnut St @ Page Rd',
#    'on_street': 'Walnut Street',
#    'platform_code': None,
#    'platform_name': None,
#    'vehicle_type': 3,
#    'wheelchair_boarding': 1},
#   'id': '82851',
#   'links': {'self': '/stops/82851'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=82851'}},
#    'parent_station': {'data': None},
#    'recommended_transfers': {},
#    'zone': {'data': {'id': 'LocalBus', 'type': 'zone'}}},
#   'type': 'stop'},
#  {'attributes': {'address': None,
#    'at_street': None,
#    'description': 'Forest Hills - Top of Orange Line platform north escalator',
#    'latitude': 42.300859,
#    'location_type': 3,
#    'longitude': -71.114109,
#    'municipality': 'Boston',
#    'name': 'Forest Hills',
#    'on_street': None,
#    'platform_code': None,
#    'platform_name': None,
#    'vehicle_type': None,
#    'wheelchair_boarding': 1},
#   'id': 'node-129-lobby',
#   'links': {'self': '/stops/node-129-lobby'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=node-129-lobby'}},
#    'parent_station': {'data': {'id': 'place-forhl', 'type': 'stop'}},
#    'recommended_transfers': {},
#    'zone': {'data': None}},
#   'type': 'stop'},
#  {'attributes': {'address': None,
#    'at_street': 'Banks Place',
#    'description': None,
#    'latitude': 42.443302,
#    'location_type': 0,
#    'longitude': -71.068052,
#    'municipality': 'Melrose',
#    'name': 'Main St @ Banks Pl',
#    'on_street': 'Main Street',
#    'platform_code': None,
#    'platform_name': None,
#    'vehicle_type': 3,
#    'wheelchair_boarding': 0},
#   'id': '9221',
#   'links': {'self': '/stops/9221'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=9221'}},
#    'parent_station': {'data': None},
#    'recommended_transfers': {},
#    'zone': {'data': {'id': 'LocalBus', 'type': 'zone'}}},
#   'type': 'stop'},
#  {'attributes': {'address': None,
#    'at_street': 'Hillsdale Road',
#    'description': None,
#    'latitude': 42.139833,
#    'location_type': 0,
#    'longitude': -71.006985,
#    'municipality': 'Holbrook',
#    'name': 'S Franklin St opp Hillsdale Rd',
#    'on_street': 'South Franklin Street',
#    'platform_code': None,
#    'platform_name': None,
#    'vehicle_type': 3,
#    'wheelchair_boarding': 0},
#   'id': '4001',
#   'links': {'self': '/stops/4001'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=4001'}},
#    'parent_station': {'data': None},
#    'recommended_transfers': {},
#    'zone': {'data': {'id': 'LocalBus', 'type': 'zone'}}},
#   'type': 'stop'},
#  {'attributes': {'address': None,
#    'at_street': 'Babcock Street',
#    'description': None,
#    'latitude': 42.266353,
#    'location_type': 0,
#    'longitude': -70.968781,
#    'municipality': 'Quincy',
#    'name': 'Sea St @ Babcock St',
#    'on_street': 'Sea Street',
#    'platform_code': None,
#    'platform_name': None,
#    'vehicle_type': 3,
#    'wheelchair_boarding': 0},
#   'id': '3253',
#   'links': {'self': '/stops/3253'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=3253'}},
#    'parent_station': {'data': None},
#    'recommended_transfers': {},
#    'zone': {'data': {'id': 'LocalBus', 'type': 'zone'}}},
#   'type': 'stop'},
#  {'attributes': {'address': None,
#    'at_street': None,
#    'description': 'Kendall/MIT - Main St, Buses, Cambridge Center',
#    'latitude': 42.362259,
#    'location_type': 2,
#    'longitude': -71.086206,
#    'municipality': 'Cambridge',
#    'name': 'Kendall/MIT - Main St, Buses, Cambridge Center',
#    'on_street': None,
#    'platform_code': None,
#    'platform_name': None,
#    'vehicle_type': None,
#    'wheelchair_boarding': 1},
#   'id': 'door-knncl-sbmain',
#   'links': {'self': '/stops/door-knncl-sbmain'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=door-knncl-sbmain'}},
#    'parent_station': {'data': {'id': 'place-knncl', 'type': 'stop'}},
#    'recommended_transfers': {},
#    'zone': {'data': None}},
#   'type': 'stop'},
#  {'attributes': {'address': None,
#    'at_street': None,
#    'description': 'Rockport - Commuter Rail Shuttle',
#    'latitude': 42.656052,
#    'location_type': 0,
#    'longitude': -70.626669,
#    'municipality': 'Rockport',
#    'name': 'Rockport',
#    'on_street': None,
#    'platform_code': None,
#    'platform_name': 'Commuter Rail Shuttle',
#    'vehicle_type': 3,
#    'wheelchair_boarding': 1},
#   'id': 'Rockport-S',
#   'links': {'self': '/stops/Rockport-S'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=Rockport-S'}},
#    'parent_station': {'data': {'id': 'place-GB-0353', 'type': 'stop'}},
#    'recommended_transfers': {},
#    'zone': {'data': {'id': 'LocalBus', 'type': 'zone'}}},
#   'type': 'stop'},
#  {'attributes': {'address': None,
#    'at_street': 'Craig Lane',
#    'description': None,
#    'latitude': 42.395355,
#    'location_type': 0,
#    'longitude': -71.247958,
#    'municipality': 'Waltham',
#    'name': 'Totten Pond Rd opp Craig Ln',
#    'on_street': 'Totten Pond Road',
#    'platform_code': None,
#    'platform_name': None,
#    'vehicle_type': 3,
#    'wheelchair_boarding': 0},
#   'id': '89608',
#   'links': {'self': '/stops/89608'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=89608'}},
#    'parent_station': {'data': None},
#    'recommended_transfers': {},
#    'zone': {'data': {'id': 'LocalBus', 'type': 'zone'}}},
#   'type': 'stop'},
#  {'attributes': {'address': None,
#    'at_street': None,
#    'description': 'Arlington - Bottom of stairs from westbound escalator',
#    'latitude': None,
#    'location_type': 3,
#    'longitude': None,
#    'municipality': 'Boston',
#    'name': 'Arlington',
#    'on_street': None,
#    'platform_code': None,
#    'platform_name': None,
#    'vehicle_type': None,
#    'wheelchair_boarding': 1},
#   'id': 'node-armnl-wescstairs-lobby',
#   'links': {'self': '/stops/node-armnl-wescstairs-lobby'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=node-armnl-wescstairs-lobby'}},
#    'parent_station': {'data': {'id': 'place-armnl', 'type': 'stop'}},
#    'recommended_transfers': {},
#    'zone': {'data': None}},
#   'type': 'stop'},
#  {'attributes': {'address': None,
#    'at_street': None,
#    'description': None,
#    'latitude': 42.303676,
#    'location_type': 0,
#    'longitude': -70.919766,
#    'municipality': 'Hull',
#    'name': 'Pemberton Point',
#    'on_street': 'Main Street',
#    'platform_code': None,
#    'platform_name': None,
#    'vehicle_type': 3,
#    'wheelchair_boarding': 0},
#   'id': '111146',
#   'links': {'self': '/stops/111146'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=111146'}},
#    'parent_station': {'data': None},
#    'recommended_transfers': {},
#    'zone': {'data': {'id': 'LocalBus', 'type': 'zone'}}},
#   'type': 'stop'},
#  {'attributes': {'address': None,
#    'at_street': 'Sables Court',
#    'description': None,
#    'latitude': 42.416769,
#    'location_type': 0,
#    'longitude': -71.105122,
#    'municipality': 'Medford',
#    'name': '116 Riverside Ave',
#    'on_street': 'Riverside Avenue',
#    'platform_code': None,
#    'platform_name': None,
#    'vehicle_type': 3,
#    'wheelchair_boarding': 0},
#   'id': '9172',
#   'links': {'self': '/stops/9172'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=9172'}},
#    'parent_station': {'data': None},
#    'recommended_transfers': {},
#    'zone': {'data': {'id': 'LocalBus', 'type': 'zone'}}},
#   'type': 'stop'},
#  {'attributes': {'address': None,
#    'at_street': 'Keller Path',
#    'description': None,
#    'latitude': 42.29108,
#    'location_type': 0,
#    'longitude': -71.185716,
#    'municipality': 'Newton',
#    'name': 'Sawmill Brook Pkwy @ Keller Path',
#    'on_street': 'Sawmill Brook Parkway',
#    'platform_code': None,
#    'platform_name': None,
#    'vehicle_type': 3,
#    'wheelchair_boarding': 1},
#   'id': '8553',
#   'links': {'self': '/stops/8553'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=8553'}},
#    'parent_station': {'data': None},
#    'recommended_transfers': {},
#    'zone': {'data': {'id': 'LocalBus', 'type': 'zone'}}},
#   'type': 'stop'},
#  {'attributes': {'address': None,
#    'at_street': None,
#    'description': None,
#    'latitude': 42.549752,
#    'location_type': 0,
#    'longitude': -70.931153,
#    'municipality': 'Danvers',
#    'name': 'Endicott St @ Market Basket',
#    'on_street': 'Endicott Street',
#    'platform_code': None,
#    'platform_name': None,
#    'vehicle_type': 3,
#    'wheelchair_boarding': 1},
#   'id': '4614',
#   'links': {'self': '/stops/4614'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=4614'}},
#    'parent_station': {'data': None},
#    'recommended_transfers': {},
#    'zone': {'data': {'id': 'LocalBus', 'type': 'zone'}}},
#   'type': 'stop'},
#  {'attributes': {'address': None,
#    'at_street': None,
#    'description': 'World Trade Center - Bottom of inbound platform elevator',
#    'latitude': None,
#    'location_type': 3,
#    'longitude': None,
#    'municipality': 'Boston',
#    'name': 'World Trade Center',
#    'on_street': None,
#    'platform_code': None,
#    'platform_name': None,
#    'vehicle_type': None,
#    'wheelchair_boarding': 1},
#   'id': 'node-935-platform',
#   'links': {'self': '/stops/node-935-platform'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=node-935-platform'}},
#    'parent_station': {'data': {'id': 'place-wtcst', 'type': 'stop'}},
#    'recommended_transfers': {},
#    'zone': {'data': None}},
#   'type': 'stop'},
#  {'attributes': {'address': None,
#    'at_street': None,
#    'description': 'Cleveland Circle - Green Line - Park Street & North',
#    'latitude': 42.336252,
#    'location_type': 0,
#    'longitude': -71.148774,
#    'municipality': 'Boston',
#    'name': 'Cleveland Circle',
#    'on_street': None,
#    'platform_code': None,
#    'platform_name': 'Park Street & North',
#    'vehicle_type': 0,
#    'wheelchair_boarding': 1},
#   'id': '70238',
#   'links': {'self': '/stops/70238'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=70238'}},
#    'parent_station': {'data': {'id': 'place-clmnl', 'type': 'stop'}},
#    'recommended_transfers': {},
#    'zone': {'data': {'id': 'RapidTransit', 'type': 'zone'}}},
#   'type': 'stop'},
#  {'attributes': {'address': None,
#    'at_street': 'Stark Avenue',
#    'description': None,
#    'latitude': 42.41787,
#    'location_type': 0,
#    'longitude': -71.010378,
#    'municipality': 'Revere',
#    'name': 'Malden St @ Stark Ave',
#    'on_street': 'Malden Street',
#    'platform_code': None,
#    'platform_name': None,
#    'vehicle_type': 3,
#    'wheelchair_boarding': 0},
#   'id': '6250',
#   'links': {'self': '/stops/6250'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=6250'}},
#    'parent_station': {'data': None},
#    'recommended_transfers': {},
#    'zone': {'data': {'id': 'LocalBus', 'type': 'zone'}}},
#   'type': 'stop'},
#  {'attributes': {'address': None,
#    'at_street': 'Longwood Avenue',
#    'description': None,
#    'latitude': 42.339097,
#    'location_type': 0,
#    'longitude': -71.106836,
#    'municipality': 'Boston',
#    'name': 'Brookline Ave @ Longwood Ave',
#    'on_street': 'Brookline Avenue',
#    'platform_code': None,
#    'platform_name': None,
#    'vehicle_type': 3,
#    'wheelchair_boarding': 0},
#   'id': '1804',
#   'links': {'self': '/stops/1804'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=1804'}},
#    'parent_station': {'data': None},
#    'recommended_transfers': {},
#    'zone': {'data': {'id': 'LocalBus', 'type': 'zone'}}},
#   'type': 'stop'},
#  {'attributes': {'address': None,
#    'at_street': 'Winthrop Street',
#    'description': None,
#    'latitude': 42.414274,
#    'location_type': 0,
#    'longitude': -71.119813,
#    'municipality': 'Medford',
#    'name': 'George St @ Winthrop St',
#    'on_street': 'George Street',
#    'platform_code': None,
#    'platform_name': None,
#    'vehicle_type': 3,
#    'wheelchair_boarding': 1},
#   'id': '5037',
#   'links': {'self': '/stops/5037'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=5037'}},
#    'parent_station': {'data': None},
#    'recommended_transfers': {},
#    'zone': {'data': {'id': 'LocalBus', 'type': 'zone'}}},
#   'type': 'stop'},
#  {'attributes': {'address': None,
#    'at_street': 'Crescent Avenue',
#    'description': None,
#    'latitude': 42.489127,
#    'location_type': 0,
#    'longitude': -71.278935,
#    'municipality': 'Bedford',
#    'name': 'South Rd @ Crescent Ave',
#    'on_street': 'South Road',
#    'platform_code': None,
#    'platform_name': None,
#    'vehicle_type': 3,
#    'wheelchair_boarding': 0},
#   'id': '8465',
#   'links': {'self': '/stops/8465'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=8465'}},
#    'parent_station': {'data': None},
#    'recommended_transfers': {},
#    'zone': {'data': {'id': 'LocalBus', 'type': 'zone'}}},
#   'type': 'stop'},
#  {'attributes': {'address': None,
#    'at_street': None,
#    'description': 'Jackson Square - Orange Line - Oak Grove',
#    'latitude': 42.323132,
#    'location_type': 0,
#    'longitude': -71.099592,
#    'municipality': 'Boston',
#    'name': 'Jackson Square',
#    'on_street': None,
#    'platform_code': None,
#    'platform_name': 'Oak Grove',
#    'vehicle_type': 1,
#    'wheelchair_boarding': 1},
#   'id': '70007',
#   'links': {'self': '/stops/70007'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=70007'}},
#    'parent_station': {'data': {'id': 'place-jaksn', 'type': 'stop'}},
#    'recommended_transfers': {},
#    'zone': {'data': {'id': 'RapidTransit', 'type': 'zone'}}},
#   'type': 'stop'},
#  {'attributes': {'address': None,
#    'at_street': 'Saltonstall Parkway',
#    'description': None,
#    'latitude': 42.512725,
#    'location_type': 0,
#    'longitude': -70.89209,
#    'municipality': 'Salem',
#    'name': 'Lafayette St @ Saltonstall Pkwy',
#    'on_street': 'Lafayette Street',
#    'platform_code': None,
#    'platform_name': None,
#    'vehicle_type': 3,
#    'wheelchair_boarding': 0},
#   'id': '6177',
#   'links': {'self': '/stops/6177'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=6177'}},
#    'parent_station': {'data': None},
#    'recommended_transfers': {},
#    'zone': {'data': {'id': 'LocalBus', 'type': 'zone'}}},
#   'type': 'stop'},
#  {'attributes': {'address': None,
#    'at_street': 'Jefferson Avenue',
#    'description': None,
#    'latitude': 42.402028,
#    'location_type': 0,
#    'longitude': -71.035402,
#    'municipality': 'Chelsea',
#    'name': '296 Washington Ave opp Jefferson Ave',
#    'on_street': 'Washington Avenue',
#    'platform_code': None,
#    'platform_name': None,
#    'vehicle_type': 3,
#    'wheelchair_boarding': 0},
#   'id': '5598',
#   'links': {'self': '/stops/5598'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=5598'}},
#    'parent_station': {'data': None},
#    'recommended_transfers': {},
#    'zone': {'data': {'id': 'LocalBus', 'type': 'zone'}}},
#   'type': 'stop'},
#  {'attributes': {'address': None,
#    'at_street': None,
#    'description': 'Haymarket - Top of stairs between mezzanine and Oak Grove platform',
#    'latitude': None,
#    'location_type': 3,
#    'longitude': None,
#    'municipality': 'Boston',
#    'name': 'Haymarket',
#    'on_street': None,
#    'platform_code': None,
#    'platform_name': None,
#    'vehicle_type': None,
#    'wheelchair_boarding': 1},
#   'id': 'node-haecl-congogplatn-passage',
#   'links': {'self': '/stops/node-haecl-congogplatn-passage'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=node-haecl-congogplatn-passage'}},
#    'parent_station': {'data': {'id': 'place-haecl', 'type': 'stop'}},
#    'recommended_transfers': {},
#    'zone': {'data': None}},
#   'type': 'stop'},
#  {'attributes': {'address': None,
#    'at_street': None,
#    'description': 'Prudential - Prudential Center',
#    'latitude': 42.345632,
#    'location_type': 2,
#    'longitude': -71.081223,
#    'municipality': 'Boston',
#    'name': 'Prudential - Prudential Center',
#    'on_street': None,
#    'platform_code': None,
#    'platform_name': None,
#    'vehicle_type': None,
#    'wheelchair_boarding': 1},
#   'id': 'door-prmnl-prudential',
#   'links': {'self': '/stops/door-prmnl-prudential'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=door-prmnl-prudential'}},
#    'parent_station': {'data': {'id': 'place-prmnl', 'type': 'stop'}},
#    'recommended_transfers': {},
#    'zone': {'data': None}},
#   'type': 'stop'},
#  {'attributes': {'address': None,
#    'at_street': 'Putnam Street',
#    'description': None,
#    'latitude': 42.377644,
#    'location_type': 0,
#    'longitude': -71.03133,
#    'municipality': 'Boston',
#    'name': 'Bennington St @ Putnam St',
#    'on_street': 'Bennington Street',
#    'platform_code': None,
#    'platform_name': None,
#    'vehicle_type': 3,
#    'wheelchair_boarding': 0},
#   'id': '5870',
#   'links': {'self': '/stops/5870'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=5870'}},
#    'parent_station': {'data': None},
#    'recommended_transfers': {},
#    'zone': {'data': {'id': 'LocalBus', 'type': 'zone'}}},
#   'type': 'stop'},
#  {'attributes': {'address': None,
#    'at_street': 'Charles Street',
#    'description': None,
#    'latitude': 42.192747,
#    'location_type': 0,
#    'longitude': -71.059709,
#    'municipality': 'Randolph',
#    'name': 'N Main St @ Charles St',
#    'on_street': 'North Main Street',
#    'platform_code': None,
#    'platform_name': None,
#    'vehicle_type': 3,
#    'wheelchair_boarding': 0},
#   'id': '4297',
#   'links': {'self': '/stops/4297'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=4297'}},
#    'parent_station': {'data': None},
#    'recommended_transfers': {},
#    'zone': {'data': {'id': 'LocalBus', 'type': 'zone'}}},
#   'type': 'stop'},
#  {'attributes': {'address': None,
#    'at_street': 'Unnamed Road',
#    'description': None,
#    'latitude': 42.481345,
#    'location_type': 0,
#    'longitude': -71.123476,
#    'municipality': 'Woburn',
#    'name': '42 Central St',
#    'on_street': 'Central Street',
#    'platform_code': None,
#    'platform_name': None,
#    'vehicle_type': 3,
#    'wheelchair_boarding': 1},
#   'id': '49903',
#   'links': {'self': '/stops/49903'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=49903'}},
#    'parent_station': {'data': None},
#    'recommended_transfers': {},
#    'zone': {'data': {'id': 'LocalBus', 'type': 'zone'}}},
#   'type': 'stop'},
#  {'attributes': {'address': None,
#    'at_street': 'Dexter Street',
#    'description': None,
#    'latitude': 42.398961,
#    'location_type': 0,
#    'longitude': -71.102197,
#    'municipality': 'Medford',
#    'name': 'Main St @ Dexter St',
#    'on_street': 'Main Street',
#    'platform_code': None,
#    'platform_name': None,
#    'vehicle_type': 3,
#    'wheelchair_boarding': 1},
#   'id': '5300',
#   'links': {'self': '/stops/5300'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=5300'}},
#    'parent_station': {'data': None},
#    'recommended_transfers': {},
#    'zone': {'data': {'id': 'LocalBus', 'type': 'zone'}}},
#   'type': 'stop'},
#  {'attributes': {'address': None,
#    'at_street': 'West Roxbury Parkway',
#    'description': None,
#    'latitude': 42.275418,
#    'location_type': 0,
#    'longitude': -71.140573,
#    'municipality': 'Boston',
#    'name': 'Washington St @ W Roxbury Pkwy',
#    'on_street': 'Washington Street',
#    'platform_code': None,
#    'platform_name': None,
#    'vehicle_type': 3,
#    'wheelchair_boarding': 0},
#   'id': '608',
#   'links': {'self': '/stops/608'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=608'}},
#    'parent_station': {'data': None},
#    'recommended_transfers': {},
#    'zone': {'data': {'id': 'LocalBus', 'type': 'zone'}}},
#   'type': 'stop'},
#  {'attributes': {'address': None,
#    'at_street': 'Hancock Street',
#    'description': None,
#    'latitude': 42.49331,
#    'location_type': 0,
#    'longitude': -71.278346,
#    'municipality': 'Bedford',
#    'name': 'Springs Rd @ Hancock St',
#    'on_street': 'Springs Road',
#    'platform_code': None,
#    'platform_name': None,
#    'vehicle_type': 3,
#    'wheelchair_boarding': 0},
#   'id': '8467',
#   'links': {'self': '/stops/8467'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=8467'}},
#    'parent_station': {'data': None},
#    'recommended_transfers': {},
#    'zone': {'data': {'id': 'LocalBus', 'type': 'zone'}}},
#   'type': 'stop'},
#  {'attributes': {'address': None,
#    'at_street': 'Hilburn Street',
#    'description': None,
#    'latitude': 42.277378,
#    'location_type': 0,
#    'longitude': -71.127103,
#    'municipality': 'Boston',
#    'name': 'Metropolitan Ave @ Hilburn St',
#    'on_street': 'Metropolitan Avenue',
#    'platform_code': None,
#    'platform_name': None,
#    'vehicle_type': 3,
#    'wheelchair_boarding': 0},
#   'id': '2797',
#   'links': {'self': '/stops/2797'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=2797'}},
#    'parent_station': {'data': None},
#    'recommended_transfers': {},
#    'zone': {'data': {'id': 'LocalBus', 'type': 'zone'}}},
#   'type': 'stop'},
#  {'attributes': {'address': None,
#    'at_street': 'Francis Street',
#    'description': None,
#    'latitude': 42.402773,
#    'location_type': 0,
#    'longitude': -71.043325,
#    'municipality': 'Everett',
#    'name': 'Chelsea St opp Francis St',
#    'on_street': 'Chelsea Street',
#    'platform_code': None,
#    'platform_name': None,
#    'vehicle_type': 3,
#    'wheelchair_boarding': 1},
#   'id': '5644',
#   'links': {'self': '/stops/5644'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=5644'}},
#    'parent_station': {'data': None},
#    'recommended_transfers': {},
#    'zone': {'data': {'id': 'LocalBus', 'type': 'zone'}}},
#   'type': 'stop'},
#  {'attributes': {'address': None,
#    'at_street': None,
#    'description': 'Tufts Medical Center - Bottom of Escalator 147',
#    'latitude': None,
#    'location_type': 3,
#    'longitude': None,
#    'municipality': 'Boston',
#    'name': 'Tufts Medical Center',
#    'on_street': None,
#    'platform_code': None,
#    'platform_name': None,
#    'vehicle_type': None,
#    'wheelchair_boarding': 1},
#   'id': 'node-147-platform',
#   'links': {'self': '/stops/node-147-platform'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=node-147-platform'}},
#    'parent_station': {'data': {'id': 'place-tumnl', 'type': 'stop'}},
#    'recommended_transfers': {},
#    'zone': {'data': None}},
#   'type': 'stop'},
#  {'attributes': {'address': None,
#    'at_street': None,
#    'description': 'Fields Corner - Top of escalator to Alewife platform',
#    'latitude': 42.299892,
#    'location_type': 3,
#    'longitude': -71.062021,
#    'municipality': 'Boston',
#    'name': 'Fields Corner',
#    'on_street': None,
#    'platform_code': None,
#    'platform_name': None,
#    'vehicle_type': None,
#    'wheelchair_boarding': 1},
#   'id': 'node-427-platform',
#   'links': {'self': '/stops/node-427-platform'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=node-427-platform'}},
#    'parent_station': {'data': {'id': 'place-fldcr', 'type': 'stop'}},
#    'recommended_transfers': {},
#    'zone': {'data': None}},
#   'type': 'stop'},
#  {'attributes': {'address': None,
#    'at_street': None,
#    'description': 'Courthouse - Thomson Pl, Seaport Blvd',
#    'latitude': 42.352247,
#    'location_type': 2,
#    'longitude': -71.046901,
#    'municipality': 'Boston',
#    'name': 'Courthouse - Thomson Pl, Seaport Blvd',
#    'on_street': None,
#    'platform_code': None,
#    'platform_name': None,
#    'vehicle_type': None,
#    'wheelchair_boarding': 1},
#   'id': 'door-crtst-south',
#   'links': {'self': '/stops/door-crtst-south'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=door-crtst-south'}},
#    'parent_station': {'data': {'id': 'place-crtst', 'type': 'stop'}},
#    'recommended_transfers': {},
#    'zone': {'data': None}},
#   'type': 'stop'},
#  {'attributes': {'address': None,
#    'at_street': 'Broadway',
#    'description': None,
#    'latitude': 42.369203,
#    'location_type': 0,
#    'longitude': -71.101015,
#    'municipality': 'Cambridge',
#    'name': 'Prospect St @ Broadway',
#    'on_street': 'Prospect Street',
#    'platform_code': None,
#    'platform_name': None,
#    'vehicle_type': 3,
#    'wheelchair_boarding': 1},
#   'id': '2448',
#   'links': {'self': '/stops/2448'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=2448'}},
#    'parent_station': {'data': None},
#    'recommended_transfers': {},
#    'zone': {'data': {'id': 'LocalBus', 'type': 'zone'}}},
#   'type': 'stop'},
#  {'attributes': {'address': None,
#    'at_street': None,
#    'description': None,
#    'latitude': 42.258447,
#    'location_type': 0,
#    'longitude': -71.081447,
#    'municipality': 'Milton',
#    'name': 'Brook Rd @ Central Ave',
#    'on_street': 'Brook Road',
#    'platform_code': None,
#    'platform_name': None,
#    'vehicle_type': 3,
#    'wheelchair_boarding': 0},
#   'id': '4404',
#   'links': {'self': '/stops/4404'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=4404'}},
#    'parent_station': {'data': None},
#    'recommended_transfers': {},
#    'zone': {'data': {'id': 'LocalBus', 'type': 'zone'}}},
#   'type': 'stop'},
#  {'attributes': {'address': None,
#    'at_street': 'Columbia Road',
#    'description': None,
#    'latitude': 42.413444,
#    'location_type': 0,
#    'longitude': -71.108991,
#    'municipality': 'Medford',
#    'name': 'Mystic Ave @ Columbia Rd',
#    'on_street': 'Mystic Avenue',
#    'platform_code': None,
#    'platform_name': None,
#    'vehicle_type': 3,
#    'wheelchair_boarding': 0},
#   'id': '2889',
#   'links': {'self': '/stops/2889'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=2889'}},
#    'parent_station': {'data': None},
#    'recommended_transfers': {},
#    'zone': {'data': {'id': 'LocalBus', 'type': 'zone'}}},
#   'type': 'stop'},
#  {'attributes': {'address': None,
#    'at_street': None,
#    'description': 'Symphony - Paid side of fare gates',
#    'latitude': None,
#    'location_type': 3,
#    'longitude': None,
#    'municipality': 'Boston',
#    'name': 'Symphony',
#    'on_street': None,
#    'platform_code': None,
#    'platform_name': None,
#    'vehicle_type': None,
#    'wheelchair_boarding': 1},
#   'id': 'node-symcl-wb-farepaid',
#   'links': {'self': '/stops/node-symcl-wb-farepaid'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=node-symcl-wb-farepaid'}},
#    'parent_station': {'data': {'id': 'place-symcl', 'type': 'stop'}},
#    'recommended_transfers': {},
#    'zone': {'data': None}},
#   'type': 'stop'},
#  {'attributes': {'address': None,
#    'at_street': 'Willow Street',
#    'description': None,
#    'latitude': 42.38837,
#    'location_type': 0,
#    'longitude': -71.026854,
#    'municipality': 'Chelsea',
#    'name': 'Central Ave @ Willow St',
#    'on_street': 'Central Avenue',
#    'platform_code': None,
#    'platform_name': None,
#    'vehicle_type': 3,
#    'wheelchair_boarding': 0},
#   'id': '5674',
#   'links': {'self': '/stops/5674'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=5674'}},
#    'parent_station': {'data': None},
#    'recommended_transfers': {},
#    'zone': {'data': {'id': 'LocalBus', 'type': 'zone'}}},
#   'type': 'stop'},
#  {'attributes': {'address': None,
#    'at_street': 'Columbia Avenue',
#    'description': None,
#    'latitude': 42.314177,
#    'location_type': 0,
#    'longitude': -71.21603,
#    'municipality': 'Newton',
#    'name': 'Elliot St @ Columbia Ave',
#    'on_street': 'Elliot Street',
#    'platform_code': None,
#    'platform_name': None,
#    'vehicle_type': 3,
#    'wheelchair_boarding': 0},
#   'id': '8209',
#   'links': {'self': '/stops/8209'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=8209'}},
#    'parent_station': {'data': None},
#    'recommended_transfers': {},
#    'zone': {'data': {'id': 'LocalBus', 'type': 'zone'}}},
#   'type': 'stop'},
#  {'attributes': {'address': None,
#    'at_street': 'Highland Avenue',
#    'description': None,
#    'latitude': 42.410149,
#    'location_type': 0,
#    'longitude': -71.175919,
#    'municipality': 'Arlington',
#    'name': 'West Service Rd @ Pedestrian Bridge',
#    'on_street': 'Frontage Road',
#    'platform_code': None,
#    'platform_name': None,
#    'vehicle_type': 3,
#    'wheelchair_boarding': 0},
#   'id': '2355',
#   'links': {'self': '/stops/2355'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=2355'}},
#    'parent_station': {'data': None},
#    'recommended_transfers': {},
#    'zone': {'data': {'id': 'LocalBus', 'type': 'zone'}}},
#   'type': 'stop'},
#  {'attributes': {'address': None,
#    'at_street': None,
#    'description': None,
#    'latitude': 42.383968,
#    'location_type': 0,
#    'longitude': -71.092101,
#    'municipality': 'Somerville',
#    'name': 'Medford St @ Highland Ave',
#    'on_street': 'Medford Street',
#    'platform_code': None,
#    'platform_name': None,
#    'vehicle_type': 3,
#    'wheelchair_boarding': 0},
#   'id': '2688',
#   'links': {'self': '/stops/2688'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=2688'}},
#    'parent_station': {'data': None},
#    'recommended_transfers': {},
#    'zone': {'data': {'id': 'LocalBus', 'type': 'zone'}}},
#   'type': 'stop'},
#  {'attributes': {'address': None,
#    'at_street': 'West Street',
#    'description': None,
#    'latitude': 42.483434,
#    'location_type': 0,
#    'longitude': -70.888223,
#    'municipality': 'Marblehead',
#    'name': 'Humphrey St @ West St',
#    'on_street': 'Humphrey Street',
#    'platform_code': None,
#    'platform_name': None,
#    'vehicle_type': 3,
#    'wheelchair_boarding': 1},
#   'id': '4860',
#   'links': {'self': '/stops/4860'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=4860'}},
#    'parent_station': {'data': None},
#    'recommended_transfers': {},
#    'zone': {'data': {'id': 'LocalBus', 'type': 'zone'}}},
#   'type': 'stop'},
#  {'attributes': {'address': None,
#    'at_street': None,
#    'description': None,
#    'latitude': 42.242995,
#    'location_type': 0,
#    'longitude': -70.948461,
#    'municipality': 'Weymouth',
#    'name': 'Sea St @ Bridge St',
#    'on_street': 'Sea Street',
#    'platform_code': None,
#    'platform_name': None,
#    'vehicle_type': 3,
#    'wheelchair_boarding': 1},
#   'id': '3708',
#   'links': {'self': '/stops/3708'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=3708'}},
#    'parent_station': {'data': None},
#    'recommended_transfers': {},
#    'zone': {'data': {'id': 'LocalBus', 'type': 'zone'}}},
#   'type': 'stop'},
#  {'attributes': {'address': None,
#    'at_street': 'Elliot Avenue',
#    'description': None,
#    'latitude': 42.266943,
#    'location_type': 0,
#    'longitude': -71.03587,
#    'municipality': 'Quincy',
#    'name': 'Harvard St @ Elliot Ave',
#    'on_street': 'Harvard Street',
#    'platform_code': None,
#    'platform_name': None,
#    'vehicle_type': 3,
#    'wheelchair_boarding': 0},
#   'id': '3116',
#   'links': {'self': '/stops/3116'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=3116'}},
#    'parent_station': {'data': None},
#    'recommended_transfers': {},
#    'zone': {'data': {'id': 'LocalBus', 'type': 'zone'}}},
#   'type': 'stop'},
#  {'attributes': {'address': 'Fellsway St and Milton St, Dorchester, MA 02124',
#    'at_street': None,
#    'description': None,
#    'latitude': 42.279682,
#    'location_type': 1,
#    'longitude': -71.060432,
#    'municipality': 'Boston',
#    'name': 'Cedar Grove',
#    'on_street': None,
#    'platform_code': None,
#    'platform_name': None,
#    'vehicle_type': None,
#    'wheelchair_boarding': 1},
#   'id': 'place-cedgr',
#   'links': {'self': '/stops/place-cedgr'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=place-cedgr'}},
#    'parent_station': {'data': None},
#    'recommended_transfers': {},
#    'zone': {'data': None}},
#   'type': 'stop'},
#  {'attributes': {'address': None,
#    'at_street': 'Kimball Avenue',
#    'description': None,
#    'latitude': 42.486346,
#    'location_type': 0,
#    'longitude': -71.197685,
#    'municipality': 'Burlington',
#    'name': 'S Bedford St opp Kimball Ave',
#    'on_street': 'South Bedford Street',
#    'platform_code': None,
#    'platform_name': None,
#    'vehicle_type': 3,
#    'wheelchair_boarding': 0},
#   'id': '49739',
#   'links': {'self': '/stops/49739'},
#   'relationships': {'child_stops': {},
#    'facilities': {'links': {'related': '/facilities/?filter[stop]=49739'}},
#    'parent_station': {'data': None},
#    'recommended_transfers': {},
#    'zone': {'data': {'id': 'LocalBus', 'type': 'zone'}}},
#   'type': 'stop'}]

# %%
response3_data[0].keys()
# Out:
# dict_keys(['attributes', 'id', 'links', 'relationships', 'type'])

# %%
response3.url
# Out:
# 'https://api-v3.mbta.com/stops?page%5Blimit%5D=50'

# %%
response3.status_code
# Out:
# 200

# %%
route_id = 'red'
response4 = session.get(f"{mbta_url}/stops", params = {'filter[route]':route_id})

# %%
response4.status_code
# Out:
# 200

# %%
response4.text
# Out:
# '{"data":[],"jsonapi":{"version":"1.0"}}'

# %%
'links' in response4.json()
# Out:
# False
